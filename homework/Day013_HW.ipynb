# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find(class_='article-meta-value').text)

    
    except:
        continue

for d in soup.find_all(class_="date"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('date')['0']).text, "html5lib")
        print('時間: ' + r.find(class_='article-meta-value').text)
    except:
        continue
# Out:
# (已被Vedan刪除) <maxsdtime>1-1(150)
# [新聞] NBA戰術板 居然MADE IN TAIWAN
# 作者: SAC430 (sac430)
# [討論] 人們將追逐 Bogdan Bogdanovic
# 作者: humbler (獸人H)
# [討論] 哪隻奪冠球隊適合Kevin Love
# 作者: KevinLove (Kevin Love)
# [新聞] 保羅遭火箭隊交易 安東尼：曾叫他要小心
# 作者: Angel0724 (ND5)
# Re: [討論] AD現在有比巔峰KG強嗎？(數據)
# 作者: MrSatan (老大!!!!!!!!)
# Re: [討論] AD現在有比巔峰KG強嗎？
# 作者: iammatrix ()
# [公告] 板規v6.6
# [公告] 樂透取消及未來不再開啟樂透
# 作者: Vedan (味丹)
# [公告] 版主上任相關事項
# 作者: qazwsx879345 (Rajon Rondo)
# [情報] SEASON Schedule 賽程 December 19–20
# 作者: JerroLi (銀色小刀)
# [公告]是否禁止basketball top 5文章投票開始
# 作者: dragon803 (好想去露營啊~)
# 12/10
# 12/10
# 12/10
# 12/10
# 12/10
# 12/10
# 12/10
#  5/24
#  6/24
# 10/25
# 11/29
# 12/08

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/C_GameBoard/index1.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find(class_='article-meta-value').text)

    
    except:
        continue

for d in soup.find_all(class_="date"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('date')['0']).text, "html5lib")
        print('時間: ' + r.find(class_='article-meta-value').text)
    except:
        continue
# Out:
# [公告] TypeMoon 板板主警告一次
# 作者: sitos (麥子)
# Fw: [公告] 小組長徵選進度更新 (2019/5/21)
# 作者: sitos (麥子)
# Fw: [申請] nicetree 申請擔任 AC_Game 小組長
# 作者: nicetree (nicetree)
# Fw: [申請] endlesschaos 申請擔任 AC_Game 小組長
# 作者: TED9999 (泰德賜酒)
# Fw: [申請] jschenlemn 申請擔任 AC_Game 小組長
# 作者: sitos (麥子)
# Fw: [申請] endlesschaos 申請擔任 AC_Game 小組長
# 作者: sitos (麥子)
# [C_GameBoard] 看板 選情報導
# [C_GameBoard] 看板 選情報導
# [C_GameBoard] 看板 選情報導
# Fw: [公告] 實習小組長上任
# 作者: sitos (麥子)
# [公告] 遊戲作品組務組規
# 作者: nicetree (nicetree)
# [公告] 遊戲作品組務板板規
# 作者: nicetree (nicetree)
# Fw: [公告] 卡漫夢工廠組規 2017.02.25版
# 作者: nicetree (nicetree)
# Re: [申請] endlesschaos 申請擔任 AC_Game 小組長
# 作者: endlesschaos (米糕)
# Fw: [公告] 辦理MemoriesOff板主投票
# 作者: nicetree (nicetree)
# Fw: [公告] 8/3 停機公告
# 作者: nicetree (nicetree)
# [看板] 《Angelique板》申請關閉自刪文章
# 作者: seanx (龍昭)
# [看板] 《Angelique板》申請變更看板名稱
# 作者: seanx (龍昭)
# Re: [看板] 《Angelique板》申請關閉自刪文章
# 作者: nicetree (nicetree)
# Re: [看板] 《Angelique板》申請變更看板名稱
# 作者: nicetree (nicetree)
#  5/13
#  5/21
#  5/22
#  5/23
#  5/28
#  5/28
# ...

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/C_GameBoard/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find(class_='article-meta-value').text)

    
    except:
        continue

for d in soup.find_all(class_="date"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('date')['0']).text, "html5lib")
        print('時間: ' + r.find(class_='article-meta-value').text)
    except:
        continue
# Out:
# Fw: [申訴] kid725 - #1SU0eDJ5 (C_ArtBoard)判決
# 作者: sitos (麥子)
# [公告] AC_Game遊戲小組遊戲心得徵文票選活動
# 作者: nicetree (nicetree)
# Re: [申訴] kid725 - #1SU0eDJ5 (C_ArtBoard)判決
# 作者: nicetree (nicetree)
# Fw: [申訴] kid725 - #1SU0m3ro (C_ArtBoard)判決
# 作者: sitos (麥子)
# Re: [申訴] kid725 - #1SU0eDJ5 (C_ArtBoard)判決
# 作者: endlesschaos (米糕)
# Re: [申訴] kid725 - #1SU0m3ro (C_ArtBoard)判決
# 作者: nicetree (nicetree)
# [AC_Game] Fate/SN Dominate Grail War 玩後感想
# 作者: kning0926 (KNING貓餃)
# [AC_Game] Fate/SN Dominate Grail War
# 作者: kning0926 (KNING貓餃)
# [AC_Game] Fate/SN Dominate Grail War
# 作者: kning0926 (KNING貓餃)
# [公告] AC_Game遊戲小組遊戲心得票選開始
# 作者: nicetree (nicetree)
# [C_GameBoard] 看板 選情報導
# [公告] AC_Game遊戲小組遊戲心得票選頒獎
# 作者: nicetree (nicetree)
# Re: [申訴] kid725 - #1SU0eDJ5 (C_ArtBoard)判決
# 作者: nicetree (nicetree)
# Re: [申訴] kid725 - #1SU0eDJ5 (C_ArtBoard)判決
# 作者: endlesschaos (米糕)
# Re: [申訴] kid725 - #1SU0m3ro (C_ArtBoard)判決
# 作者: endlesschaos (米糕)
# [公告] 遊戲作品組務組規
# 作者: nicetree (nicetree)
# [公告] 遊戲作品組務板板規
# ...
