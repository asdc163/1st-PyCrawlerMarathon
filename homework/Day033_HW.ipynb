# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36'}
cookies = {
    'dotcom_user':'asdc163',
    'logged_in':'yes',
    'user_session':'y2L9QIw7ZrM5_phYifmahcUee3ly3hlow-2kxTkjcz23y6vz'}
res = requests.get('https://github.com/new',headers=headers,cookies=cookies)
BeautifulSoup(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-02a3eaa24db2bd1ed9b64450595fc2cf.css" integrity="sha512-hddDYPWR0gBbqLRmIZP242WMEiYsVkYI2UCYCVUHB4h5DhD2cbtFJYG+HPh21dZGb+sbgDHxQBNJCBq7YbmlBQ==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-be4e45349cf088df7a6636f437c0a167.css" integrity="sha512-uhAd27cNiLn0VE2GVEVUN8D5zW0o7s0QTnCGMnJZkL2HqN9/LwHDi4ndTPJH0upUQHYl/8QF6cwbOYp/KIzlJQ==" media="all" rel="stylesheet"/>
# <meta content="width=device-width" name="viewport"/>
# <title>Create a New Repository</title>
# <meta content="GitHub is where people build software. More than 40 million people use GitHub to discover, fork, and contribute to over 100 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 40 million people use GitHub to discover, fork, and contribute to over 100 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 40 million people use GitHub to discover, fork, and contribute to over 100 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <link href="wss://live.github.com/_sockets/VjI6NDcxMDQzNzQ0OjE3MzA4ZmQ1YmM2ZTIxOGUyNWUzZTY0YmEzYjQ1MjM5N2Y5M2UzODA1ZTMzZjcyN2ZkM2YxOTVlMThlYTk4YWY=--0f674c0edf83320500753d1f6abb05826ad58141" rel="web-socket"/>
# <link href="/sessions/sudo_modal" rel="sudo-modal"/>
# <meta content="E84C:06F4:7EA550:F48D77:5E185378" data-pjax-transient="" name="request-id"/>
# <meta data-pjax-transient="" name="selected-link" value="repo_create"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="collector.githubapp.com" name="octolytics-host"/><meta content="github" name="octolytics-app-id"/><meta content="https://collector.githubapp.com/github-external/browser_event" name="octolytics-event-url"/><meta content="E84C:06F4:7EA550:F48D77:5E185378" name="octolytics-dimension-request_id"/><meta content="iad" name="octolytics-dimension-region_edge"/><meta content="iad" name="octolytics-dimension-region_render"/><meta class="js-octo-ga-id" content="" name="octolytics-dimension-ga_id"/><meta content="4519172768047584120" name="octolytics-dimension-visitor_id"/><meta content="58109713" name="octolytics-actor-id"/><meta content="asdc163" name="octolytics-actor-login"/><meta content="8f1345e0a3479d08a5b4a5ff5a55b163f0fb270c5a7df5e4998d1c600d126183" name="octolytics-actor-hash"/>
# <meta content="UA-3769691-2" name="google-analytics"/>
# <meta class="js-ga-set" content="d777613bf6951db1236e73078ae8beca" name="userId"/>
# <meta class="js-ga-set" content="Logged In" name="dimension1"/>
# <meta content="github.com" name="hostname"/>
# <meta content="asdc163" name="user-login"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="NDc3YjMyMjFkYmJiZTFmMDc5MTY2MjQ1NGU2MWNlZDViNjAyMTcyMjI0ZjBkZjg4ODczOGRhZmRlMjExOTE2NXx7InJlbW90ZV9hZGRyZXNzIjoiMS4xNjAuMTE3LjIzMyIsInJlcXVlc3RfaWQiOiJFODRDOjA2RjQ6N0VBNTUwOkY0OEQ3Nzo1RTE4NTM3OCIsInRpbWVzdGFtcCI6MTU3ODY1MjUzNiwiaG9zdCI6ImdpdGh1Yi5jb20ifQ==" name="js-proxy-site-detection-payload"/>
# <meta content="MARKETPLACE_FEATURED_BLOG_POSTS,MARKETPLACE_INVOICED_BILLING,MARKETPLACE_SOCIAL_PROOF_CUSTOMERS,MARKETPLACE_TRENDING_SOCIAL_PROOF,MARKETPLACE_RECOMMENDATIONS,MARKETPLACE_PENDING_INSTALLATIONS,NOTIFY_ON_BLOCK,RELATED_ISSUES,GHE_CLOUD_TRIAL" name="enabled-features"/>
# <meta content="09ac4a0c6ed3cfea7fc780a6fce3005484c1be9f" name="html-safe-nonce"/>
# <meta content="7dad68d15e9ec3082ddc567f6471b389" http-equiv="x-pjax-version"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicon.ico" rel="icon" type="image/x-icon"/>
# <meta content="#1e2327" name="theme-color"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </head>
# <body class="logged-in env-production min-width-lg page-new-repo">
# <div class="position-relative js-header-wrapper">
# <a class="p-3 bg-blue text-white show-on-focus js-skip-to-content" href="#start-of-content" tabindex="1">Skip to content</a>
# <span class="Progress progress-pjax-loader position-fixed width-full js-pjax-loader-bar">
# <span class="progress-pjax-loader-bar top-0 left-0" style="width: 0%;"></span>
# </span>
# <header class="Header" role="banner">
# <div class="Header-item">
# <a aria-label="Homepage" class="Header-link" data-ga-click="Header, go to dashboard, icon:logo" data-hotkey="g d" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github v-align-middle" height="32" version="1.1" viewbox="0 0 16 16" width="32"><path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path></svg>
# </a>
# </div>
# <div class="Header-item Header-item--full">
# <div aria-expanded="false" aria-haspopup="listbox" aria-label="Search or jump to" aria-owns="jump-to-results" class="header-search mr-3 js-site-search position-relative js-jump-to" role="combobox">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/search" aria-label="Site" class="js-site-search-form" data-unscoped-search-url="/search" method="get" role="search"><input name="utf8" type="hidden" value="✓"/>
# <label class="form-control input-sm header-search-wrapper p-0 header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center js-chromeless-input-container">
# <input aria-autocomplete="list" aria-controls="jump-to-results" aria-label="Search or jump to…" autocapitalize="off" autocomplete="off" class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations#csrf-token=9Nna+1RCZcFQyQW8BuWfOZZ5Sj0rLFWuHzlstP1w6PVHL4+nQ6QRQqaoxaIVW5Gsiep096KAA449PKUvJQWq1w==" data-scoped-placeholder="Search or jump to…" data-unscoped-placeholder="Search or jump to…" name="q" placeholder="Search or jump to…" spellcheck="false" type="text" value=""/>
# <input class="js-site-search-type-field" name="type" type="hidden"/>
# <img alt="" class="mr-2 header-search-key-slash" src="https://github.githubassets.com/images/search-key-slash.svg"/>
# <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
# <ul class="d-none js-jump-to-suggestions-template-container">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16"><path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 00-1 1v14a1 1 0 001 1h13a1 1 0 001-1V1a1 1 0 00-1-1z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0013 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 000-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="d-none js-jump-to-no-results-template-container">
# <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
# <span class="text-gray">No suggested jump to results</span>
# </li>
# </ul>
# <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16"><path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 00-1 1v14a1 1 0 001 1h13a1 1 0 001-1V1a1 1 0 00-1-1z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0013 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 000-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16"><path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 00-1 1v14a1 1 0 001 1h13a1 1 0 001-1V1a1 1 0 00-1-1z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0013 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 000-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-center flex-items-center p-0 f5 js-jump-to-suggestion">
# <img alt="Octocat Spinner Icon" class="m-2" src="https://github.githubassets.com/images/spinners/octocat-spinner-128.gif" width="28"/>
# </li>
# </ul>
# </div>
# </label>
# </form> </div>
# </div>
# <nav aria-label="Global" class="d-flex">
# <a aria-label="Pull requests you created" class="js-selected-navigation-item Header-link mr-3" data-ga-click="Header, click, Nav menu - item:pulls context:user" data-hotkey="g p" data-selected-links="/pulls /pulls/assigned /pulls/mentioned /pulls" href="/pulls">
#     Pull requests
# </a>
# <a aria-label="Issues you created" class="js-selected-navigation-item Header-link mr-3" data-ga-click="Header, click, Nav menu - item:issues context:user" data-hotkey="g i" data-selected-links="/issues /issues/assigned /issues/mentioned /issues" href="/issues">
#     Issues
# </a>
# <div class="mr-3">
# <a class="js-selected-navigation-item Header-link" data-ga-click="Header, click, Nav menu - item:marketplace context:user" data-octo-click="marketplace_click" data-octo-dimensions="location:nav_bar" data-selected-links=" /marketplace" href="/marketplace">
#         Marketplace
# </a>
# </div>
# <a class="js-selected-navigation-item Header-link mr-3" data-ga-click="Header, click, Nav menu - item:explore" data-selected-links="/explore /trending /trending/developers /integrations /integrations/feature/code /integrations/feature/collaborate /integrations/feature/ship showcases showcases_search showcases_landing /explore" href="/explore">
#     Explore
# </a>
# </nav>
# </div>
# <div class="Header-item">
# <a aria-label="You have no unread notifications" class="Header-link notification-indicator position-relative tooltipped tooltipped-sw js-socket-channel js-notification-indicator" data-channel="notification-changed:58109713" data-ga-click="Header, go to notifications, icon:read" data-hotkey="g n" href="/notifications">
# <span class="mail-status"></span>
# <svg aria-hidden="true" class="octicon octicon-bell" height="16" version="1.1" viewbox="0 0 14 16" width="14"><path d="M14 12v1H0v-1l.73-.58c.77-.77.81-2.55 1.19-4.42C2.69 3.23 6 2 6 2c0-.55.45-1 1-1s1 .45 1 1c0 0 3.39 1.23 4.16 5 .38 1.88.42 3.66 1.19 4.42l.66.58H14zm-7 4c1.11 0 2-.89 2-2H5c0 1.11.89 2 2 2z" fill-rule="evenodd"></path></svg>
# </a>
# </div>
# <div class="Header-item position-relative">
# <details class="details-overlay details-reset">
# <summary aria-label="Create new…" class="Header-link" data-ga-click="Header, create new, icon:add">
# <svg aria-hidden="true" class="octicon octicon-plus" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 9H7v5H5V9H0V7h5V2h2v5h5v2z" fill-rule="evenodd"></path></svg> <span class="dropdown-caret"></span>
# </summary>
# <details-menu class="dropdown-menu dropdown-menu-sw">
# <a class="dropdown-item" data-ga-click="Header, create new repository" href="/new" role="menuitem">
#   New repository
# </a>
# <a class="dropdown-item" data-ga-click="Header, import a repository" href="/new/import" role="menuitem">
#     Import repository
#   </a>
# <a class="dropdown-item" data-ga-click="Header, create new gist" href="https://gist.github.com/" role="menuitem">
#   New gist
# </a>
# <a class="dropdown-item" data-ga-click="Header, create new organization" href="/organizations/new" role="menuitem">
#     New organization
#   </a>
# <a class="dropdown-item" data-ga-click="Header, create new project" href="/new/project" role="menuitem">
#     New project
#   </a>
# </details-menu>
# </details>
# </div>
# <div class="Header-item position-relative mr-0">
# <details class="details-overlay details-reset js-feature-preview-indicator-container" data-feature-preview-indicator-src="/users/asdc163/feature_preview/indicator_check.json">
# <summary aria-label="View profile and more" class="Header-link" data-ga-click="Header, show menu, icon:avatar">
# <img alt="@asdc163" class="avatar" height="20" src="https://avatars2.githubusercontent.com/u/58109713?s=40&amp;v=4" width="20"/>
# <span class="feature-preview-indicator js-feature-preview-indicator" hidden=""></span>
# <span class="dropdown-caret"></span>
# </summary>
# <details-menu class="dropdown-menu dropdown-menu-sw mt-2" style="width: 180px">
# <div class="header-nav-current-user css-truncate"><a class="no-underline user-profile-link px-3 pt-2 pb-2 mb-n2 mt-n1 d-block" data-ga-click="Header, go to profile, text:Signed in as" href="/asdc163" role="menuitem">Signed in as <strong class="css-truncate-target">asdc163</strong></a></div>
# <div class="dropdown-divider" role="none"></div>
# <div class="pl-3 pr-3 f6 user-status-container js-user-status-context pb-1" data-url="/users/status?compact=1&amp;link_mentions=0&amp;truncate=1">
# <div class="js-user-status-container user-status-compact rounded-1 px-2 py-1 mt-2 border" data-team-hovercards-enabled="">
# <details class="js-user-status-details details-reset details-overlay details-overlay-dark">
# <summary class="btn-link btn-block link-gray no-underline js-toggle-user-status-edit toggle-user-status-edit" role="menuitem">
# <div class="d-flex">
# <div class="f6 lh-condensed user-status-header d-inline-block v-align-middle user-status-emoji-only-header circle pr-2" style="max-width: 29px">
# <div class="user-status-emoji-container flex-shrink-0 mr-1 mt-1 lh-condensed-ultra v-align-bottom" style="">
# <svg aria-hidden="true" class="octicon octicon-smiley" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 0C3.58 0 0 3.58 0 8s3.58 8 8 8 8-3.58 8-8-3.58-8-8-8zm4.81 12.81a6.72 6.72 0 01-2.17 1.45c-.83.36-1.72.53-2.64.53-.92 0-1.81-.17-2.64-.53-.81-.34-1.55-.83-2.17-1.45a6.773 6.773 0 01-1.45-2.17A6.59 6.59 0 011.21 8c0-.92.17-1.81.53-2.64.34-.81.83-1.55 1.45-2.17.62-.62 1.36-1.11 2.17-1.45A6.59 6.59 0 018 1.21c.92 0 1.81.17 2.64.53.81.34 1.55.83 2.17 1.45.62.62 1.11 1.36 1.45 2.17.36.83.53 1.72.53 2.64 0 .92-.17 1.81-.53 2.64-.34.81-.83 1.55-1.45 2.17zM4 6.8v-.59c0-.66.53-1.19 1.2-1.19h.59c.66 0 1.19.53 1.19 1.19v.59c0 .67-.53 1.2-1.19 1.2H5.2C4.53 8 4 7.47 4 6.8zm5 0v-.59c0-.66.53-1.19 1.2-1.19h.59c.66 0 1.19.53 1.19 1.19v.59c0 .67-.53 1.2-1.19 1.2h-.59C9.53 8 9 7.47 9 6.8zm4 3.2c-.72 1.88-2.91 3-5 3s-4.28-1.13-5-3c-.14-.39.23-1 .66-1h8.59c.41 0 .89.61.75 1z" fill-rule="evenodd"></path></svg>
# </div>
# </div>
# <div class="d-inline-block v-align-middle css-truncate css-truncate-target user-status-message-wrapper f6" style="line-height: 20px;">
# <div class="d-inline-block text-gray-dark v-align-text-top text-left">
# <span class="text-gray ml-2">Set status</span>
# </div>
# </div>
# </div>
# </summary>
# <details-dialog class="details-dialog rounded-1 anim-fade-in fast Box Box--overlay" role="dialog" tabindex="-1">
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/users/status?compact=1&amp;link_mentions=0&amp;truncate=1" class="position-relative flex-auto js-user-status-form" method="post"><input name="utf8" type="hidden" value="✓"/><input name="_method" type="hidden" value="put"/><input name="authenticity_token" type="hidden" value="9SeBsjD65jvpQ5H6jGqCnnZdUmN/NyrcvEC/htEy8Q0woG+vCcU7NaW/QBopZGHzTQxpRGTl4zPpysq1LPrgfw=="/>
# <div class="Box-header bg-gray border-bottom p-3">
# <button aria-label="Close dialog" class="Box-btn-octicon js-toggle-user-status-edit btn-octicon float-right" data-close-dialog="" type="reset">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd"></path></svg>
# </button>
# <h3 class="Box-title f5 text-bold text-gray-dark">Edit status</h3>
# </div>
# <input class="js-user-status-emoji-field" name="emoji" type="hidden" value=""/>
# <input class="js-user-status-org-id-field" name="organization_id" type="hidden" value=""/>
# <div class="px-3 py-2 text-gray-dark">
# <div class="js-characters-remaining-container position-relative mt-2">
# <div class="input-group d-table form-group my-0 js-user-status-form-group">
# <span class="input-group-button d-table-cell v-align-middle" style="width: 1%">
# <button aria-label="Choose an emoji" class="btn-outline btn js-toggle-user-status-emoji-picker btn-open-emoji-picker p-0" type="button">
# <span class="js-user-status-original-emoji" hidden=""></span>
# <span class="js-user-status-custom-emoji"></span>
# <span class="js-user-status-no-emoji-icon">
# <svg aria-hidden="true" class="octicon octicon-smiley" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 0C3.58 0 0 3.58 0 8s3.58 8 8 8 8-3.58 8-8-3.58-8-8-8zm4.81 12.81a6.72 6.72 0 01-2.17 1.45c-.83.36-1.72.53-2.64.53-.92 0-1.81-.17-2.64-.53-.81-.34-1.55-.83-2.17-1.45a6.773 6.773 0 01-1.45-2.17A6.59 6.59 0 011.21 8c0-.92.17-1.81.53-2.64.34-.81.83-1.55 1.45-2.17.62-.62 1.36-1.11 2.17-1.45A6.59 6.59 0 018 1.21c.92 0 1.81.17 2.64.53.81.34 1.55.83 2.17 1.45.62.62 1.11 1.36 1.45 2.17.36.83.53 1.72.53 2.64 0 .92-.17 1.81-.53 2.64-.34.81-.83 1.55-1.45 2.17zM4 6.8v-.59c0-.66.53-1.19 1.2-1.19h.59c.66 0 1.19.53 1.19 1.19v.59c0 .67-.53 1.2-1.19 1.2H5.2C4.53 8 4 7.47 4 6.8zm5 0v-.59c0-.66.53-1.19 1.2-1.19h.59c.66 0 1.19.53 1.19 1.19v.59c0 .67-.53 1.2-1.19 1.2h-.59C9.53 8 9 7.47 9 6.8zm4 3.2c-.72 1.88-2.91 3-5 3s-4.28-1.13-5-3c-.14-.39.23-1 .66-1h8.59c.41 0 .89.61.75 1z" fill-rule="evenodd"></path></svg>
# </span>
# </button>
# </span>
# <text-expander data-emoji-url="/autocomplete/emoji" data-mention-url="/autocomplete/user-suggestions" keys=": @">
# <input aria-label="What is your current status?" autocomplete="off" class="d-table-cell width-full form-control js-user-status-message-field js-characters-remaining-field" data-maxlength="80" data-no-org-url="/autocomplete/user-suggestions" data-org-url="/suggestions?mention_suggester=1" name="message" placeholder="What's happening?" type="text" value=""/>
# </text-expander>
# <div class="error">Could not update your status, please try again.</div>
# </div>
# <div class="my-1 text-small label-characters-remaining js-characters-remaining" data-suffix="remaining" hidden="" style="margin-left: 53px">
#               80 remaining
#             </div>
# </div>
# <include-fragment class="js-user-status-emoji-picker" data-url="/users/status/emoji"></include-fragment>
# <div class="overflow-auto ml-n3 mr-n3 px-3 border-bottom" style="max-height: 33vh">
# <div class="user-status-suggestions js-user-status-suggestions collapsed overflow-hidden">
# <h4 class="f6 text-normal my-3">Suggestions:</h4>
# <div class="mx-3 mt-2 clearfix">
# <div class="float-left col-6">
# <button class="d-flex flex-items-baseline flex-items-stretch lh-condensed f6 btn-link link-gray no-underline js-predefined-user-status mb-1" type="button" value=":palm_tree:">
# <div class="emoji-status-width mr-2 v-align-middle js-predefined-user-status-emoji">
# <g-emoji alias="palm_tree" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f334.png">🌴</g-emoji>
# </div>
# <div class="d-flex flex-items-center no-underline js-predefined-user-status-message ws-normal text-left" style="border-left: 1px solid transparent">
#                           On vacation
#                         </div>
# </button>
# <button class="d-flex flex-items-baseline flex-items-stretch lh-condensed f6 btn-link link-gray no-underline js-predefined-user-status mb-1" type="button" value=":face_with_thermometer:">
# <div class="emoji-status-width mr-2 v-align-middle js-predefined-user-status-emoji">
# <g-emoji alias="face_with_thermometer" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f912.png">🤒</g-emoji>
# </div>
# <div class="d-flex flex-items-center no-underline js-predefined-user-status-message ws-normal text-left" style="border-left: 1px solid transparent">
#                           Out sick
#                         </div>
# </button>
# </div>
# <div class="float-left col-6">
# <button class="d-flex flex-items-baseline flex-items-stretch lh-condensed f6 btn-link link-gray no-underline js-predefined-user-status mb-1" type="button" value=":house:">
# <div class="emoji-status-width mr-2 v-align-middle js-predefined-user-status-emoji">
# <g-emoji alias="house" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f3e0.png">🏠</g-emoji>
# </div>
# <div class="d-flex flex-items-center no-underline js-predefined-user-status-message ws-normal text-left" style="border-left: 1px solid transparent">
#                           Working from home
#                         </div>
# </button>
# <button class="d-flex flex-items-baseline flex-items-stretch lh-condensed f6 btn-link link-gray no-underline js-predefined-user-status mb-1" type="button" value=":dart:">
# <div class="emoji-status-width mr-2 v-align-middle js-predefined-user-status-emoji">
# <g-emoji alias="dart" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f3af.png">🎯</g-emoji>
# </div>
# <div class="d-flex flex-items-center no-underline js-predefined-user-status-message ws-normal text-left" style="border-left: 1px solid transparent">
#                           Focusing
#                         </div>
# </button>
# </div>
# </div>
# </div>
# <div class="user-status-limited-availability-container">
# <div class="form-checkbox my-0">
# <input aria-describedby="limited-availability-help-text-truncate-true-compact-true" class="js-user-status-limited-availability-checkbox" data-default-message="I may be slow to respond." id="limited-availability-truncate-true-compact-true" name="limited_availability" type="checkbox" value="1"/>
# <label class="d-block f5 text-gray-dark mb-1" for="limited-availability-truncate-true-compact-true">
#                   Busy
#                 </label>
# <p class="note" id="limited-availability-help-text-truncate-true-compact-true">
#                   When others mention you, assign you, or request your review,
#                   GitHub will let them know that you have limited availability.
#                 </p>
# </div>
# </div>
# </div>
# <div class="d-inline-block f5 mr-2 pt-3 pb-2">
# <div class="d-inline-block mr-1">
#     Clear status
#   </div>
# <details class="js-user-status-expire-drop-down f6 dropdown details-reset details-overlay d-inline-block mr-2">
# <summary aria-haspopup="true" class="f5 btn-link link-gray-dark border px-2 py-1 rounded-1">
# <div class="js-user-status-expiration-interval-selected d-inline-block v-align-baseline">
#         Never
#       </div>
# <div class="dropdown-caret"></div>
# </summary>
# <ul class="dropdown-menu dropdown-menu-se pl-0 overflow-auto" style="width: 220px; max-height: 15.5em">
# <li>
# <button class="btn-link dropdown-item js-user-status-expire-button ws-normal" title="Never" type="button">
# <span class="d-inline-block text-bold mb-1">Never</span>
# <div class="f6 lh-condensed">Keep this status until you clear your status or edit your status.</div>
# </button>
# </li>
# <li class="dropdown-divider" role="none"></li>
# <li>
# <button class="btn-link dropdown-item ws-normal js-user-status-expire-button" title="in 30 minutes" type="button" value="2020-01-10T11:05:36Z">
#             in 30 minutes
#           </button>
# </li>
# <li>
# <button class="btn-link dropdown-item ws-normal js-user-status-expire-button" title="in 1 hour" type="button" value="2020-01-10T11:35:36Z">
#             in 1 hour
#           </button>
# </li>
# <li>
# <button class="btn-link dropdown-item ws-normal js-user-status-expire-button" title="in 4 hours" type="button" value="2020-01-10T14:35:36Z">
#             in 4 hours
#           </button>
# </li>
# <li>
# <button class="btn-link dropdown-item ws-normal js-user-status-expire-button" title="today" type="button" value="2020-01-10T23:59:59Z">
#             today
#           </button>
# </li>
# <li>
# <button class="btn-link dropdown-item ws-normal js-user-status-expire-button" title="this week" type="button" value="2020-01-12T23:59:59Z">
#             this week
#           </button>
# </li>
# </ul>
# </details>
# <input class="js-user-status-expiration-date-input" name="expires_at" type="hidden" value=""/>
# </div>
# <include-fragment class="js-user-status-org-picker" data-url="/users/status/organizations"></include-fragment>
# </div>
# <div class="d-flex flex-items-center flex-justify-between p-3 border-top">
# <button class="width-full btn btn-primary mr-2 js-user-status-submit" disabled="" type="submit">
#             Set status
#           </button>
# <button class="width-full js-clear-user-status-button btn ml-2" disabled="" type="button">
#             Clear status
#           </button>
# </div>
# </form> </details-dialog>
# </details>
# </div>
# </div>
# <div class="dropdown-divider" role="none"></div>
# <a class="dropdown-item" data-ga-click="Header, go to profile, text:your profile" href="/asdc163" role="menuitem">Your profile</a>
# <a class="dropdown-item" data-ga-click="Header, go to repositories, text:your repositories" href="/asdc163?tab=repositories" role="menuitem">Your repositories</a>
# <a class="dropdown-item" data-ga-click="Header, go to projects, text:your projects" href="/asdc163?tab=projects" role="menuitem">Your projects</a>
# <a class="dropdown-item" data-ga-click="Header, go to starred repos, text:your stars" href="/asdc163?tab=stars" role="menuitem">Your stars</a>
# <a class="dropdown-item" data-ga-click="Header, your gists, text:your gists" href="https://gist.github.com/mine" role="menuitem">Your gists</a>
# <div class="dropdown-divider" role="none"></div>
# <div class="hide-sm hide-md feature-preview-details position-relative" id="feature-enrollment-toggle">
# <button class="dropdown-item btn-link" data-feature-preview-close-details='{"event_type":"feature_preview.clicks.close_modal","payload":{"client_id":null,"originating_request_id":"E84C:06F4:7EA550:F48D77:5E185378","originating_url":"https://github.com/new","referrer":null,"user_id":58109713}}' data-feature-preview-close-hmac="cf5a9e38dd282cbe125302931859397eb019c0c3c0fde25f80c91a75586b0dc6" data-feature-preview-trigger-url="/users/asdc163/feature_previews" data-hydro-click='{"event_type":"feature_preview.clicks.open_modal","payload":{"link_location":"user_dropdown","client_id":null,"originating_request_id":"E84C:06F4:7EA550:F48D77:5E185378","originating_url":"https://github.com/new","referrer":null,"user_id":58109713}}' data-hydro-click-hmac="1aa5ae1c42001981b5e489f696eea770413e8d3686fa4f956cb7a44191832f2d" role="menuitem" type="button">
#     Feature preview
#   </button>
# <span class="feature-preview-indicator js-feature-preview-indicator" hidden=""></span>
# </div>
# <a class="dropdown-item" data-ga-click="Header, go to help, text:help" href="https://help.github.com" role="menuitem">Help</a>
# <a class="dropdown-item" data-ga-click="Header, go to settings, icon:settings" href="/settings/profile" role="menuitem">Settings</a>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/logout" class="logout-form" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="oxhV7yOOf502PiN5HHmfawjxxTUuFOeOcvkWMbQYiL4wRdOk3eQn1vh/Q0mw6mjXg/Qef+yeAzVMmvgTdndvyA=="/>
# <button class="dropdown-item dropdown-signout" data-ga-click="Header, sign out, icon:logout" role="menuitem" type="submit">
#         Sign out
#       </button>
# <input class="form-control" hidden="hidden" name="required_field_f8ac" type="text"/>
# <input class="form-control" name="timestamp" type="hidden" value="1578652536459"/>
# <input class="form-control" name="timestamp_secret" type="hidden" value="a537e96df0226a92083d878d1c15d20adc92018d410e67fd7ea2e6acadb3fa8f"/>
# </form> </details-menu>
# </details>
# </div>
# </header>
# </div>
# <div class="show-on-focus" id="start-of-content"></div>
# <div id="js-flash-container">
# </div>
# <div class="application-main" data-commit-hovercards-enabled="">
# <main data-pjax-container="" id="js-pjax-container">
# <div class="new-repo-container">
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/repositories" aria-label="Create a new repository" class="js-braintree-encrypt" data-braintree-key="" id="new_repository" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="zq2rtgelipo8C8eWNhqCGxindPKsJyxXVq4tmLvo9kn+v40Ql5A80pP4asg065h/Ooj9LsSdS5EDz3VVFjVmQw=="/>
# <div class="Subhead">
# <h2 class="Subhead-heading">Create a new repository</h2>
# <p class="Subhead-description">
#       A repository contains all project files, including the revision history.
#
#         Already have a project repository elsewhere? <a data-ga-click="Create Repository, import repository, location:repo new" data-hydro-click='{"event_type":"repository_create.click","payload":{"event_target":"IMPORT_REPOSITORY_LINK","client_id":null,"originating_request_id":"E84C:06F4:7EA550:F48D77:5E185378","originating_url":"https://github.com/new","referrer":null,"user_id":58109713}}' data-hydro-click-hmac="dc77e851bc5494e515946cbbaab8ab0a36704f8da62a5a2d50b70938fddf75b3" href="/new/import">Import a repository.</a>
# </p>
# </div>
# <div class="owner-reponame clearfix">
# <dl class="form-group float-left">
# <dt><label for="repository-owner" id="repository-owner-label">Owner</label></dt>
# <dd>
# <details class="js-owner-container position-relative details-reset details-overlay select-menu">
# <summary aria-describedby="repository-owner-label" class="btn select-menu-button with-gravatar js-owner-select" data-menu-button="" id="repository-owner">
# <img alt="" class="avatar select-menu-item-gravatar" height="20" src="https://avatars2.githubusercontent.com/u/58109713?s=40&amp;v=4" width="20"/>
#     asdc163
#   </summary>
# <details-menu aria-labelledby="repository-owner-label" class="select-menu-modal position-absolute" preload="" src="/users/asdc163/organizations_info?owner_id=58109713" style="z-index: 99;">
# <div class="select-menu-list">
# <label aria-checked="true" class="select-menu-item" data-default="public" data-permission="yes" data-user-show-trade-controls="false" role="menuitemradio" tabindex="0">
# <input checked="" class="js-repository-owner-choice js-repository-owner-is-viewer" name="owner" type="radio" value="asdc163"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <template class="js-quick-install-list-template" hidden="">
# <div data-login="asdc163">
# </div>
# </template>
# <div class="select-menu-item-text" data-menu-button-contents="">
# <img alt="" class="avatar select-menu-item-gravatar" height="20" src="https://avatars2.githubusercontent.com/u/58109713?s=40&amp;v=4" width="20"/>
#       asdc163
#     </div>
# </label>
# </div>
# </details-menu>
# </details>
# </dd>
# </dl>
# <span class="slash js-with-permission-fields">/</span>
# <auto-check csrf="y1oACQ/cJa4GMcbuFUldGXBk+YlG794N6PSB2DxE4qGAHsBP6TVLAb1Fih1Q/dKDPQyBTEtvS8iLipQL+OCCVg==" src="/repositories/check-name">
# <dl class="form-group float-left js-with-permission-fields required"><dt class="input-label"><label aria-describedby="repo-name-suggestion" autocapitalize="off" for="repository_name" maxlength="100" required="required">Repository name</label></dt><dd><input aria-describedby="repo-name-suggestion" autocapitalize="off" class="form-control js-repo-name js-repo-name-auto-check short" id="repository_name" maxlength="100" name="repository[name]" required="required" size="100" type="text"/></dd></dl>
# </auto-check>
# </div>
# <div class="js-with-permission-fields">
# <p class="my-2" id="repo-name-suggestion">
#         Great repository names are short and memorable. Need inspiration? How about
#         <strong class="reponame-suggestion js-reponame-suggestion">redesigned-octo-guide</strong>?
#       </p>
# <!-- description field -->
# <dl class="form-group"><dt class="input-label"><label autocomplete="off" for="repository_description">Description <span class="note">(optional)</span></label></dt><dd><input autocomplete="off" class="form-control long" id="repository_description" name="repository[description]" type="text"/></dd></dl>
# <hr/>
# <!-- privacy options -->
# <div class="form-checkbox">
# <label class="js-privacy-toggle-label-public">
# <input aria-describedby="public-description" checked="checked" class="mt-2 js-privacy-toggle" id="repository_visibility_public" name="repository[visibility]" type="radio" value="public"/>
#           Public
#         </label>
# <svg aria-hidden="true" class="octicon octicon-repo float-left mt-1 mr-2" height="32" version="1.1" viewbox="0 0 12 16" width="24"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
# <span class="js-public-description note" id="public-description">
#             Anyone can see this repository. You choose who can commit.
#         </span>
# <span class="js-public-restricted-by-policy-description note overflow-hidden" hidden="">
#           You may not create public repositories by organization policy.
#         </span>
# </div>
# <div class="form-checkbox">
# <label class="js-privacy-toggle-label-private">
# <input aria-describedby="private-description upgrade-private-description" class="mt-2 js-privacy-toggle" id="repository_visibility_private" name="repository[visibility]" type="radio" value="private"/>
#           Private
#         </label>
# <svg aria-hidden="true" class="octicon octicon-lock color-private-icon float-left mt-1 mr-2" height="32" version="1.1" viewbox="0 0 12 16" width="24"><path d="M4 13H3v-1h1v1zm8-6v7c0 .55-.45 1-1 1H1c-.55 0-1-.45-1-1V7c0-.55.45-1 1-1h1V4c0-2.2 1.8-4 4-4s4 1.8 4 4v2h1c.55 0 1 .45 1 1zM3.8 6h4.41V4c0-1.22-.98-2.2-2.2-2.2-1.22 0-2.2.98-2.2 2.2v2H3.8zM11 7H2v7h9V7zM4 8H3v1h1V8zm0 2H3v1h1v-1z" fill-rule="evenodd"></path></svg>
# <span class="note js-private-description" id="private-description">
#           You choose who can see and commit to this repository.
#         </span>
# <span class="js-private-restricted-by-policy-description note overflow-hidden" hidden="">
#           You may not create private repositories by organization policy.
#         </span>
# <span class="js-trade-controls-description note overflow-hidden" hidden="">
#           Due to U.S. trade controls law restrictions, paid GitHub organization services have been restricted.
#
# For free organization accounts, you may have access to free GitHub public repository services (such as access to GitHub Pages and public repositories used for open source projects) for personal communications only, and not for commercial purposes. The restriction also includes suspended access to private repository services and paid services (such as availability of private organizational accounts and GitHub Marketplace services).
#
# Please read about <a href="https://help.github.com/articles/github-and-trade-controls">GitHub and Trade Controls</a> for more information.
#
#         </span>
# <span class="js-individual-trade-controls-description note overflow-hidden" hidden="">
#           Due to U.S. trade controls law restrictions, your GitHub account has been restricted.
#
# This means we have suspended access to private repository services and paid services for your account. For free individual accounts, you still have access to free GitHub public repository services (such as public repositories for open source projects and associated GitHub Pages and Gists).
#
# If you believe your account has been flagged in error, and you are not located in or resident in a sanctioned region, please <a href="https://airtable.com/shrGBcceazKIoz6pY">file an appeal</a>.
#
# Please read about <a href="https://help.github.com/articles/github-and-trade-controls">GitHub and Trade Controls</a> for more information.
#
#         </span>
# <span class="js-upgrade-private-description note overflow-hidden" hidden="">
#           Your current plan does not support private repositories.
#             <span class="js-ask-owner-message">
#               Your organization's owners will need to upgrade to Team.
#             </span>
# </span>
# </div>
# <!-- upgrade upsell -->
# <div id="js-upgrade-container">
# <!-- Each org/user has its own billing partial that gets inserted here. See below (outside of the form). -->
# </div>
# <div class="js-repository-auto-init-options">
# <hr/>
# <p class="mt-3">Skip this step if you’re importing an existing repository.</p>
# <!-- auto init -->
# <div class="form-checkbox unchecked mt-0 mb-3">
# <label>
# <input name="repository[auto_init]" type="hidden" value="0"/><input class="js-repository-readme-choice" id="repository_auto_init" name="repository[auto_init]" type="checkbox" value="1"/>
#             Initialize this repository with a README
#           </label>
# <span class="note">
#             This will let you immediately clone the repository to your computer.
#           </span>
# </div>
# <ul class="repo-templates">
# <li>
# <details class="details-reset details-overlay select-menu">
# <summary class="btn btn-sm select-menu-button">
# <i>Add .gitignore:</i>
# <span data-menu-button="">None</span>
# </summary>
# <details-menu class="select-menu-modal position-absolute" style="z-index: 99;">
# <div class="select-menu-header">
# <span class="select-menu-title">.gitignore</span>
# </div>
# <div class="select-menu-filters">
# <div class="select-menu-text-filter">
# <input aria-label="Choose .gitignore type" autofocus="" class="form-control js-filterable-field js-navigation-enable" id="context-ignore-filter-field" placeholder="Filter ignores…" type="text"/>
# </div>
# </div>
# <div class="select-menu-list">
# <div data-filterable-for="context-ignore-filter-field">
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input checked="checked" class="js-repository-no-gitignore-choice" id="repository_gitignore_template_" name="repository[gitignore_template]" type="radio" value=""/>
# ...
# <fuzzy-list min-score="-1">
# <div class="select-menu-header">
# <span class="select-menu-title">Licenses</span>
# </div>
# <div class="select-menu-filters">
# <div class="select-menu-text-filter">
# <input aria-label="Choose a license" autofocus="" class="form-control" placeholder="Filter licenses…" type="text"/>
# </div>
# </div>
# <ul class="select-menu-list">
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input checked="checked" class="js-repository-no-license-choice" id="repository_license_template_" name="repository[license_template]" type="radio" value=""/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text text-bold" data-menu-button-text="">None</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_apache-2.0" name="repository[license_template]" type="radio" value="apache-2.0"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text" data-menu-button-text="">Apache License 2.0</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_gpl-3.0" name="repository[license_template]" type="radio" value="gpl-3.0"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text" data-menu-button-text="">GNU General Public License v3.0</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_mit" name="repository[license_template]" type="radio" value="mit"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text" data-menu-button-text="">MIT License</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_bsd-2-clause" name="repository[license_template]" type="radio" value="bsd-2-clause"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text text-normal" data-menu-button-text="">BSD 2-Clause "Simplified" License</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_bsd-3-clause" name="repository[license_template]" type="radio" value="bsd-3-clause"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text text-normal" data-menu-button-text="">BSD 3-Clause "New" or "Revised" License</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_cc0-1.0" name="repository[license_template]" type="radio" value="cc0-1.0"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text text-normal" data-menu-button-text="">Creative Commons Zero v1.0 Universal</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_epl-2.0" name="repository[license_template]" type="radio" value="epl-2.0"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text text-normal" data-menu-button-text="">Eclipse Public License 2.0</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_agpl-3.0" name="repository[license_template]" type="radio" value="agpl-3.0"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text text-normal" data-menu-button-text="">GNU Affero General Public License v3.0</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_gpl-2.0" name="repository[license_template]" type="radio" value="gpl-2.0"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text text-normal" data-menu-button-text="">GNU General Public License v2.0</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_lgpl-2.1" name="repository[license_template]" type="radio" value="lgpl-2.1"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text text-normal" data-menu-button-text="">GNU Lesser General Public License v2.1</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_lgpl-3.0" name="repository[license_template]" type="radio" value="lgpl-3.0"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text text-normal" data-menu-button-text="">GNU Lesser General Public License v3.0</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_mpl-2.0" name="repository[license_template]" type="radio" value="mpl-2.0"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text text-normal" data-menu-button-text="">Mozilla Public License 2.0</span>
# </label>
# </li>
# <li>
# <label class="select-menu-item" role="menuitemradio" tabindex="0">
# <input id="repository_license_template_unlicense" name="repository[license_template]" type="radio" value="unlicense"/>
# <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd"></path></svg>
# <span class="select-menu-item-text text-normal" data-menu-button-text="">The Unlicense</span>
# </label>
# </li>
# </ul>
# <div class="p-2" fuzzy-list-empty="" hidden="">Nothing to show</div>
# </fuzzy-list>
# </details-menu>
# </details>
# <a aria-label="Need help picking a license? We’ve built a site just for you." class="ml-2 mt-1 float-left tooltipped tooltipped-s" href="https://choosealicense.com" target="_blank">
# <svg aria-hidden="true" class="octicon octicon-info" height="16" version="1.1" viewbox="0 0 14 16" width="14"><path d="M6.3 5.69a.942.942 0 01-.28-.7c0-.28.09-.52.28-.7.19-.18.42-.28.7-.28.28 0 .52.09.7.28.18.19.28.42.28.7 0 .28-.09.52-.28.7a1 1 0 01-.7.3c-.28 0-.52-.11-.7-.3zM8 7.99c-.02-.25-.11-.48-.31-.69-.2-.19-.42-.3-.69-.31H6c-.27.02-.48.13-.69.31-.2.2-.3.44-.31.69h1v3c.02.27.11.5.31.69.2.2.42.31.69.31h1c.27 0 .48-.11.69-.31.2-.19.3-.42.31-.69H8V7.98v.01zM7 2.3c-3.14 0-5.7 2.54-5.7 5.68 0 3.14 2.56 5.7 5.7 5.7s5.7-2.55 5.7-5.7c0-3.15-2.56-5.69-5.7-5.69v.01zM7 .98c3.86 0 7 3.14 7 7s-3.14 7-7 7-7-3.12-7-7 3.14-7 7-7z" fill-rule="evenodd"></path></svg>
# </a>
# </li>
# </ul>
# </div>
# <div class="js-quick-install-container">
# <hr class="js-quick-install-divider" hidden=""/>
# <div class="js-account-apps">
# <div data-login="asdc163">
# </div>
# </div>
# </div>
# <hr/>
# <button class="btn btn-primary first-in-line" data-disable-with="Creating repository…" type="submit">
#         Create repository
#       </button>
# </div><!-- /.js-with-permission-fields -->
# <div class="js-without-permission-fields mt-2" hidden="">
# <div class="flash flash-warn">
#         You don’t appear to have permission to create repositories for this organization. Sorry about that.
#       </div>
# </div>
# </form></div><!-- /.new-repo-container -->
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/new" id="js-payment-methods-form" method="post" style="display:none"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="EOjaEtVtm0J/NYo9/od0opKGVvGGNDAUlYsrmBYSrsEmxvN/Ghegu5neLAqK6WpSJby9IjgNhoMxIR5WdYCf+w=="/></form>
# </main>
# </div>
# <div class="footer container-lg width-full px-3" role="contentinfo">
# <div class="position-relative d-flex flex-justify-between pt-6 pb-2 mt-6 f6 text-gray border-top border-gray-light">
# <ul class="list-style-none d-flex flex-wrap">
# <li class="mr-3">© 2020 GitHub, Inc.</li>
# <li class="mr-3"><a data-ga-click="Footer, go to terms, text:terms" href="https://github.com/site/terms">Terms</a></li>
# <li class="mr-3"><a data-ga-click="Footer, go to privacy, text:privacy" href="https://github.com/site/privacy">Privacy</a></li>
# <li class="mr-3"><a data-ga-click="Footer, go to security, text:security" href="https://github.com/security">Security</a></li>
# <li class="mr-3"><a data-ga-click="Footer, go to status, text:status" href="https://githubstatus.com/">Status</a></li>
# <li><a data-ga-click="Footer, go to help, text:help" href="https://help.github.com">Help</a></li>
# </ul>
# <a aria-label="Homepage" class="footer-octicon d-none d-lg-block mx-lg-4" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" height="24" version="1.1" viewbox="0 0 16 16" width="24"><path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path></svg>
# </a>
# <ul class="list-style-none d-flex flex-wrap">
# <li class="mr-3"><a data-ga-click="Footer, go to contact, text:contact" href="https://github.com/contact">Contact GitHub</a></li>
# <li class="mr-3"><a data-ga-click="Footer, go to Pricing, text:Pricing" href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3"><a data-ga-click="Footer, go to api, text:api" href="https://developer.github.com">API</a></li>
# <li class="mr-3"><a data-ga-click="Footer, go to training, text:training" href="https://training.github.com">Training</a></li>
# <li class="mr-3"><a data-ga-click="Footer, go to blog, text:blog" href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 text-gray-light"></span>
# </div>
# </div>
# <div class="ajax-error-message flash flash-error" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8.893 1.5c-.183-.31-.52-.5-.887-.5s-.703.19-.886.5L.138 13.499a.98.98 0 000 1.001c.193.31.53.501.886.501h13.964c.367 0 .704-.19.877-.5a1.03 1.03 0 00.01-1.002L8.893 1.5zm.133 11.497H6.987v-2.003h2.039v2.003zm0-3.004H6.987V5.987h2.039v4.006z" fill-rule="evenodd"></path></svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd"></path></svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <script crossorigin="anonymous" integrity="sha512-/VSJJF96vCzSgC6y09Z4FqzjjuXRWOKIq2twF0Nb5/v8xy4qzngnH6Au6TFwbmNN/lborYJsojEpgIbYjoGvHQ==" src="https://github.githubassets.com/assets/frameworks-fd548924.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-qbd68yGA3fNczkRQ63SLsQ7HbtIFTrsLsWIcT+HhA5Qp7gBUlv2izDZzDn/IrfbyuW+ci1CY91L/Zv2ML1dShw==" src="https://github.githubassets.com/assets/github-bootstrap-a9b77af3.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-7+lhrGRALVY13DuomqiLsHhllETGp9+253LGcYXlWJ3VKKdzLSW5V6XaG7vFmSrj3hhxIp9RLDxWHEALMa16tw==" src="https://github.githubassets.com/assets/billing-efe961ac.js" type="application/javascript"></script>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8.893 1.5c-.183-.31-.52-.5-.887-.5s-.703.19-.886.5L.138 13.499a.98.98 0 000 1.001c.193.31.53.501.886.501h13.964c.367 0 .704-.19.877-.5a1.03 1.03 0 00.01-1.002L8.893 1.5zm.133 11.497H6.987v-2.003h2.039v2.003zm0-3.004H6.987V5.987h2.039v4.006z" fill-rule="evenodd"></path></svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default text-gray-dark hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd"></path></svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box box-shadow-large" style="width:360px;">
# </div>
# </div>
# <div aria-live="polite" class="js-global-screen-reader-notice sr-only"></div>
# </body>
# </html>
